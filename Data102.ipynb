# %% [markdown]
# <a href="https://colab.research.google.com/github/Suphattha/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import pandas as pd
base_path = '/content/drive/My Drive/DWDM_material'
data = pd.read_csv(os.path.join(base_path,'test.csv'))
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# #Boxplot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['y'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f28d7994860>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f28d792b2b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f28d792bd30>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f28d792b9b0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f28d7994b70>,
#   <matplotlib.lines.Line2D at 0x7f28d7994ef0>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f28d745f9e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f28d746d438>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f28d746deb8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f28d746db38>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f28d745fcf8>,
#   <matplotlib.lines.Line2D at 0x7f28d746d0b8>]}

# %%
plt.boxplot(data['x'],vert=False,whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f28d790d160>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f28d748ea58>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f28d741ad68>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f28d7486208>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f28d7476710>,
#   <matplotlib.lines.Line2D at 0x7f28d74224e0>]}

# %%
oput=plt.boxplot(data['x'],vert=False,whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='p',alpha=0.4)
plt.scatter([],[])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k',marker=',') 
plt.scatter([50],[80],s=50,c='r') 
plt.scatter([50],[80],s=200,alpha=0.4,c='r')  
plt.scatter([24,26,28,30,32,34,36,38,40,42],[94,94,94,94,94,94,94,94,94,94],c='k',s=100,marker='*')
plt.scatter([34,32,30,28,26,24,22],[83,85,87,89,91,93,95],c='y',s=100,marker='*')
plt.scatter([84,86,88,90,92,94,96,98,100,100,100,98,96,94,92,90,88,86,84,82,82,82,82,82,82],[35,38,41,44,47,50,53,56,59,63,68,72,75,74,71,68,65,61,58,54,50,46,42,38,35],s=100,alpha=0.6,c='lightskyblue',marker='<')
plt.scatter([82,84,86,88,90,92.5,95,97.5,99,100,101],[65,68,71,74,77,80,82,80,77,74,71],s=100,alpha=0.6,c='lightskyblue',marker='<')
plt.scatter([44,45],[13,5])

# %%
plt.plot(data['x'],data['y'])

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.scatter(data['x'][0],data['y'][0],s=200,c='k')

# %%
plt.plot(data['x'],data['y'],'r-')
plt.scatter(data['x'],data['y'],s=range(10,len(data['x'])+10),c='c')

# %%
plt.scatter(data['x'],data['y'],s=250,c=[[0.2,0.1,0.4,0.5]])

# %%
color_list = []
for i in range(len(data['x'])) :
     color_list.append([0.2,0.1,i/255,0.5]) 
color_list
# Out:
# [[0.2, 0.1, 0.0, 0.5],
#  [0.2, 0.1, 0.00392156862745098, 0.5],
#  [0.2, 0.1, 0.00784313725490196, 0.5],
#  [0.2, 0.1, 0.011764705882352941, 0.5],
#  [0.2, 0.1, 0.01568627450980392, 0.5],
#  [0.2, 0.1, 0.0196078431372549, 0.5],
#  [0.2, 0.1, 0.023529411764705882, 0.5],
#  [0.2, 0.1, 0.027450980392156862, 0.5],
#  [0.2, 0.1, 0.03137254901960784, 0.5],
#  [0.2, 0.1, 0.03529411764705882, 0.5],
#  [0.2, 0.1, 0.0392156862745098, 0.5],
#  [0.2, 0.1, 0.043137254901960784, 0.5],
#  [0.2, 0.1, 0.047058823529411764, 0.5],
#  [0.2, 0.1, 0.050980392156862744, 0.5],
#  [0.2, 0.1, 0.054901960784313725, 0.5],
#  [0.2, 0.1, 0.058823529411764705, 0.5],
#  [0.2, 0.1, 0.06274509803921569, 0.5],
#  [0.2, 0.1, 0.06666666666666667, 0.5],
#  [0.2, 0.1, 0.07058823529411765, 0.5],
#  [0.2, 0.1, 0.07450980392156863, 0.5],
#  [0.2, 0.1, 0.0784313725490196, 0.5],
#  [0.2, 0.1, 0.08235294117647059, 0.5],
#  [0.2, 0.1, 0.08627450980392157, 0.5],
#  [0.2, 0.1, 0.09019607843137255, 0.5],
# ...

# %%
plt.scatter(data['x'],data['y'],s=250,c=color_list)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
x = np.arange(len(labels))  
width = 0.35

# %%
plt.bar(x - width/2, men_means, width, label='Men') #ทำแบบง่าย
plt.bar(x + width/2, women_means, width, label='Women')
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
plt.ylabel('Scores') 
plt.title('Scores by group and gender')
plt.legend() ;

# %%
fig, ax = plt.subplots()  
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')
ax.set_ylabel('Scores') 
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# %% [markdown]
# ##Histogram

# %%
x=[12,25,7,7,1,1,1,1,5,5,5,5]

# %%
plt.hist(x)
# Out:
# (array([4., 4., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('a a a s d f a s d f s a d f e w r w e f s d f'.split())
# Out:
# (array([5., 4., 0., 4., 0., 5., 2., 0., 2., 1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)
